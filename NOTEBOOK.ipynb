# %% [markdown]
# # Homework №2

# %% [markdown]
# This homework will be dedicated to **ASR & Co**.
#
# In general, you may implement any ASR model that was discussed in the lecture,
# but we recommend to implement **QuartzNet**.
#
# ## **Important aspects (model)**
# 1) Pay attention on different length of utterances. P.S. **masking**.
#
# 2) A good ASR is a robust ASR, so we ask you to implement and use at least **4 types of augmentations** (P.S. 2 seminar).
#
# 3) Also, to get better quality, we ask you to implement a **beam search** for better decoding.
#
# 4) (Bonus) As a bonus you can use **BPE** instead of Char. You can use SentencePiece, HuggingFace or YouTokenToMe.
#
# 5) (Bonus) As a bonus you can take pretrained **LM** (or train yourself) and fusing LM with ASR.
#     Way of fusing you may choose yourself.
#
# ## **Important aspects (code)**
# 1) You already know about pytorch-lighting (I hope :)) but you are not allowed to use it in this homework.
#
# 2) Try to write code more structurally and cleanly !
#
# 3) Good logging of experiments save your nerves and time,
#     so we ask you to use **W&B** and log at least loss, WER, CER and pairs (audio -- recognized text).
#     **Do not remove** the logs until we have checked your work and given you a grade!
#
# 4) We also ask you to organize your code in github repo with Docker and setup.py. You can use my template https://github.com/markovka17/dl-start-pack.
#
# 5) Your work **must be** reproducable, so fix seed, save the weights of model, and etc.
#
# 6) In the end of your work write inference utils. Anyone should be able to take your weight, load it into the model and run it on some audio track.
#
# ## Data

# %% [markdown]
# CommonVoice Mozilla: https://commonvoice.mozilla.org/en/datasets
# Он весит 50 гигабайт. В нем значительно больше коротких записей, что должно ускорить сходимость методов на нем.
# Можно обучиться на нем всем или просто отщипнуть себе кусочек.
#
# Все еще настоятельно рекомендую препроцессить датасет и выкидывать все записи длиннее N-секунд (а если вы учите не CTC, то стоит еще дополнительно выкидывать все записи длиннее  K символов), чтобы максимизировать размер батча.

# %% [markdown]
# ##### config

# %% [markdown]
# https://github.com/NVIDIA/NeMo/blob/main/examples/asr/conf/quartznet_15x5.yaml

# %% [markdown]
# ### Начинаем решение

# %%
import wandb

# %%
import string
import re
import math
import random
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
import librosa
import asrtoolkit
import torch_optimizer



from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from torch.optim.lr_scheduler import StepLR
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch import distributions

from collections import Counter
from IPython import display as display_
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/kirill/.local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['random', 'test', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
BATCH_SIZE = 80
NUM_EPOCHS = 10
N_MELS     = 64

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ### Датасет

# %%
class TrainDataset(torch.utils.data.Dataset):
    """Custom competition dataset."""

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.answers = pd.read_csv(csv_file, '\t')
        self.transform = transform


    def __len__(self):
        return len(self.answers)


    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        utt_name = 'cv-corpus-5.1-2020-06-22/en/clips/' + self.answers.loc[idx, 'path']
        utt = torchaudio.load(utt_name)[0].squeeze()
        
        if len(utt.shape) != 1:
            print(utt.shape)
            print(utt)
            utt = utt[1]
            
        answer = self.answers.loc[idx, 'sentence']

        if self.transform:
            utt = self.transform(utt)

        sample = {'utt': utt, 'answer': answer}
        return sample

# %%
class TestDataset(torch.utils.data.Dataset):
    """Custom competition dataset."""

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.names = pd.read_csv(csv_file, '\t')
        self.transform = transform


    def __len__(self):
        return len(self.names)


    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        utt_name = 'cv-corpus-5.1-2020-06-22/en/clips/' + self.names.loc[idx, 'path']
        utt = torchaudio.load(utt_name)[0].squeeze()
  

        if self.transform:
            utt = self.transform(utt)

        sample = {'utt': utt}
        return sample

# %% [markdown]
# #### Аугментации

# %%
def transform_tr(wav):
    aug_num = torch.randint(low=0, high=3, size=(1,)).item()
    augs = [
        lambda x: x,
        lambda x: (x + distributions.Normal(0, 0.01).sample(x.size())).clamp_(-1, 1),
        lambda x: torchaudio.transforms.Vol(.1)(x)
    ]
    
    return augs[aug_num](wav)

# %% [markdown]
# #### Визуализация

# %%
def viz(wav):
    figsize(20, 5)
    plot(wav)
    plt.show()

    display_.display(display_.Audio(wav, rate=48000, normalize=False))

# %% [markdown]
# #### Класс для кодировки текста (0 - blank_token)

# %%
class TextTransform:
    def __init__(self):
        self.char_dict = {}
        self.index_dict = {}
        
        self.char_dict['\''] = 0
        self.index_dict[0] = '\''
        self.char_dict[' '] = 1
        self.index_dict[1] = ' '
        for i, let in enumerate(string.ascii_lowercase):
            self.index_dict[i + 2] = let
            self.char_dict[let] = i + 2
            
    def text_to_int(self, text):
        labels = []
        for let in text:
            labels.append(self.char_dict[let])
        return labels
    
    def int_to_text(self, labels):
        text = []
        for num in labels:
            text.append(self.index_dict[num])
        return text

# %% [markdown]
# #### Collate_fn

# %%
#win_len=1024, hop_len=256
# counting len of MelSpec before doing it (cause of padding)
def mel_len(x):
    return int(x // 256) + 1

# %%
def preprocess_data(data):
    text_transform = TextTransform()
    wavs = []
    input_lens = []
    labels = []
    label_lens = []
    
    for el in data:
        wavs.append(el['utt'])
        input_lens.append(math.ceil(mel_len(el['utt'].shape[0]) / 2))    # cause of stride 2
        label = torch.Tensor(text_transform.text_to_int(el['answer']))
        labels.append(label)
        label_lens.append(len(label))

    wavs = pad_sequence(wavs, batch_first=True)
    labels = pad_sequence(labels, batch_first=True)
    
    return wavs, input_lens, labels, label_lens

# %%
# Loading data and loaders
my_dataset = TrainDataset(csv_file='train_preprocessed.tsv', transform=transform_tr)
print('all train+val samples:', len(my_dataset))
test_dataset = TestDataset(csv_file='cv-corpus-5.1-2020-06-22/en/test.tsv', transform=None)
# Out:
# all train+val samples: 435947

# %% [markdown]
# 100k files ~ 10GB

# %% [markdown]
# 95_percentile_len = 412416.0

# %% [markdown]
# Отсортированные по длинне звука индексы объектов.

# %%
# sorted indexes
with open('sorted.npy', 'rb') as f:
    s = np.load(f)

# %%
to_save = s[:100000][:, 0]

# %%
my_dataset = torch.utils.data.Subset(my_dataset, to_save)
train_set, val_set = torch.utils.data.random_split(my_dataset, [85000, 15000])

# %% [markdown]
# #### Даталоадеры

# %%
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE,
                          shuffle=True, collate_fn=preprocess_data, drop_last=True,
                          num_workers=0, pin_memory=True)

val_loader = DataLoader(val_set, batch_size=BATCH_SIZE,
                        shuffle=True, collate_fn=preprocess_data, drop_last=True,
                        num_workers=0, pin_memory=True)

test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, drop_last=True)

# %% [markdown]
# ## Модель

# %% [markdown]
# #### Фикс сидов и смотрим кол-во параметров

# %%
def set_seed(seed):
    torch.backends.cudnn.deterministic = True
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)
set_seed(21)

# %%
def count_parameters(model):
    model_parameters = filter(lambda p: p.requires_grad, model.parameters())
    return sum([np.prod(p.size()) for p in model_parameters])

# %% [markdown]
# #### Вспомогательные блоки

# %%
def conv_bn_act(in_size, out_size, kernel_size, stride=1, dilation=1):
    return nn.Sequential(
        nn.Conv1d(in_size, out_size, kernel_size, stride, dilation=dilation),
        nn.BatchNorm1d(out_size),
        nn.ReLU()
    )


def sepconv_bn(in_size, out_size, kernel_size, stride=1, dilation=1, padding=None):
    if padding is None:
        padding = (kernel_size-1)//2
    return nn.Sequential(
        torch.nn.Conv1d(in_size, in_size, kernel_size, 
                        stride=stride, dilation=dilation, groups=in_size,
                        padding=padding),
        torch.nn.Conv1d(in_size, out_size, kernel_size=1),
        nn.BatchNorm1d(out_size)
    )

# %%
# Основной блок B_i
class QnetBlock(nn.Module):
    def __init__(self, in_size, out_size, kernel_size, stride=1,
                R=5):
        super().__init__()
        
        self.layers = nn.ModuleList(sepconv_bn(in_size, out_size, kernel_size, stride))
        for i in range(R - 1):
            self.layers.append(nn.ReLU())
            self.layers.append(sepconv_bn(out_size, out_size, kernel_size, stride))
        self.layers = nn.Sequential(*self.layers)
        
        self.residual = nn.ModuleList()
        self.residual.append(torch.nn.Conv1d(in_size, out_size, kernel_size=1))
        self.residual.append(torch.nn.BatchNorm1d(out_size))
        self.residual = nn.Sequential(*self.residual)
    
    def forward(self, x):
        return F.relu(self.residual(x) + self.layers(x))

# %%
class QuartzNet(nn.Module):
    def __init__(self, n_mels, num_classes):
        super().__init__()
                    
        self.c1 = sepconv_bn(n_mels, 256, kernel_size=33, stride=2)
                  
        self.blocks = nn.Sequential(
                #         in   out  k   s  R
                QnetBlock(256, 256, 33, 1, R=5),
                QnetBlock(256, 256, 39, 1, R=5),
                QnetBlock(256, 512, 51, 1, R=5),
                QnetBlock(512, 512, 63, 1, R=5),
                QnetBlock(512, 512, 75, 1, R=5)
        )
        
        self.c2 = sepconv_bn(512, 512, kernel_size=87, dilation=2, padding=86)
        
        self.c3 = conv_bn_act(512, 1024, kernel_size=1)
        
        self.c4 = conv_bn_act(1024, num_classes, kernel_size=1)
        
        self.init_weights()


    def init_weights(self):
        pass


    def forward(self, x):
        c1 = F.relu(self.c1(x))
        blocks = self.blocks(c1)
        c2 = F.relu(self.c2(blocks))
        c3 = self.c3(c2)
        return self.c4(c3)

# %% [markdown]
# #### обратим внимание, что c1 и c2 тоже separable

# %% [markdown]
# ### Обучение

# %%
melspec = torchaudio.transforms.MelSpectrogram(
    sample_rate=16000,           ### 22050, 48000
    n_fft=1024,
    hop_length=256,
    n_mels=N_MELS                ### 64,    80
).to(device)


# with augmentations
melspec_transforms = nn.Sequential(
    torchaudio.transforms.MelSpectrogram(sample_rate=16000, n_fft=1024, hop_length=256,  n_mels=N_MELS),
    torchaudio.transforms.FrequencyMasking(freq_mask_param=15),
    torchaudio.transforms.TimeMasking(time_mask_param=35),
).to(device)

# %%
def train_epoch(model, optimizer, dataloader, CTCLoss, device, melspec_transforms):
    model.train()
    
    losses = []
    
    for i, (wavs, wavs_len, answ, answ_len) in tqdm(enumerate(dataloader)):
        wavs, answ = wavs.to(device), answ.to(device)
        
        trans_wavs = torch.log(melspec_transforms(wavs) + 1e-9)
        
        optimizer.zero_grad()
            
        output = model(trans_wavs)
        output = F.log_softmax(output, dim=1)
        output = output.transpose(0, 1).transpose(0, 2)        
        
        loss = CTCLoss(output, answ, wavs_len, answ_len)
        loss.backward()        
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), 15)
        optimizer.step()
        losses.append(loss.item())
        if i % 100 == 0:
            wandb.log({'mean_train_loss':loss})
            preds, targets = decoder_func(output, answ, answ_len, del_repeated=False)
            wandb.log({"CER_train": cer(targets[0], preds[0])})
            wandb.log({"WER_train": wer(targets[0], preds[0])})
        
    return np.mean(losses)

# %%
def train(model, opt, train_dl, scheduler, CTCLoss, device, n_epochs, val_dl=None):
    for epoch in range(n_epochs):
        print("Epoch {} of {}".format(epoch, n_epochs), 'LR', scheduler.get_last_lr())
        
        mean_loss = train_epoch(model, opt, train_dl, CTCLoss, device)
        print('MEAN EPOCH LOSS IS', mean_loss)
        
        scheduler.step()
        
        if (val_dl != None):
            test(model, opt, val_dl, CTCLoss, device)
            
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'scheduler_state_dict': scheduler.state_dict()
        }, 'epoch_5_and_'+str(epoch))

# %%
def decoder_func(output, answ, answ_lens, blank_label=0, del_repeated=True):    
    decoded_preds, decoded_targs = [], []
    
    text_transform = TextTransform()

    batch_freqs = torch.argmax(output, dim=2).transpose(0, 1)
        
    for i, freqs in enumerate(batch_freqs):
        preds = []
        
        decoded_targs.append(
            text_transform.int_to_text(answ[i][:answ_lens[i]].tolist())
        )
        
        for j, num in enumerate(freqs):
            if num != blank_label:
                if del_repeated and j != 0 and num == freqs[j-1]:
                    continue
                preds.append(num.item())
        decoded_preds.append(text_transform.int_to_text(preds))

    return decoded_preds, decoded_targs

# %%
def cer(target, pred):
    cer_res = asrtoolkit.cer(''.join(target), ''.join(pred))
    return cer_res

def wer(target, pred):
    wer_res = asrtoolkit.wer(''.join(target), ''.join(pred))
    return wer_res

# %%
def test(model, optimizer, dataloader, CTCLoss, device, melspec, bs_width=None):
    model.eval()
    
    cers, wers, cers_bs, wers_bs = [], [], [], []
    losses = []
    
    with torch.no_grad():
        for i, (wavs, wavs_len, answ, answ_len) in enumerate(dataloader):
            wavs, answ = wavs.to(device), answ.to(device)

            trans_wavs = torch.log(melspec(wavs) + 1e-9)

            output = model(trans_wavs)
            if bs_width != None:
                output_bs = F.softmax(output, dim=1).transpose(0, 1).transpose(0, 2)
                preds_bs, targets_bs = beam_search_decoding(output_bs, answ, answ_len, width=bs_width)
                
            output = F.log_softmax(output, dim=1)
            output = output.transpose(0, 1).transpose(0, 2)
            loss = CTCLoss(output, answ, wavs_len, answ_len)
            losses.append(loss.item())
            
            # argmax
            preds, targets = decoder_func(output, answ, answ_len, del_repeated=True)
            # beam search
            
            for i in range(len(preds)):
                if i == 0:
                    print('target: ', ''.join(targets[i]))
                    print('prediction: ', ''.join(preds[i]))
                    print('beam_search_preds: ', ''.join(preds_bs[i]))
                    
                cers.append(cer(targets[i], preds[i]))
                wers.append(wer(targets[i], preds[i]))
                cers_bs.append(cer(targets_bs[i], preds_bs[i]))
                wers_bs.append(wer(targets_bs[i], preds_bs[i]))
                
        avg_cer = np.mean(cers)
        avg_wer = np.mean(wers)
        if bs_width != None:
            avg_cer_bs = np.mean(cers_bs)
            avg_wer_bs = np.mean(wers_bs)

        
        print('CER', avg_cer)
        print('CER BS', avg_cer_bs)
        
        print('WER', avg_wer)
        print('WER BS', avg_wer_bs)
        #wandb.log({"CER_val": avg_cer})    
        #wandb.log({"WER_val": avg_wer})
        avg_loss= np.mean(losses)
        print('average test loss is', avg_loss)
        #wandb.log({'mean_VAL_loss':avg_loss})

# %%
wandb.login()
wandb.init()
train_table = wandb.Table(columns=["Predicted Text", "True Text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-256-0393b24b5bbf> in <module>
# ----> 1 wandb.login()
#       2 wandb.init()
#       3 train_table = wandb.Table(columns=["Predicted Text", "True Text"])
#
# NameError: name 'wandb' is not defined

# %%
model = QuartzNet(n_mels=64, num_classes=28)
print(count_parameters(model))
model.to(device)
wandb.watch(model)

# %%
#model = QuartzNet(n_mels=64, num_classes=28)
#num_of_params = count_parameters(model)
#model.to(device)
#wandb.watch(model)
#opt = torch.optim.RMSprop(model.parameters(), weight_decay=0.0001)
#scheduler = StepLR(opt, step_size=1, gamma=0.9) 
#checkpoint = torch.load('epoch_5', map_location=torch.device('cpu'))
#model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
opt = torch_optimizer.NovoGrad(
                        model.parameters(),
                        lr=0.01,
                        betas=(0.8, 0.5),
                        weight_decay=0.001,
)
scheduler  = CosineAnnealingLR(opt, T_max=50, eta_min=0, last_epoch=-1) # ###### TMAX = MAX NUM OF EPOCHS

#opt = torch.optim.RMSprop(model.parameters(), weight_decay=0.0001)
#scheduler = StepLR(opt, step_size=1, gamma=0.9)

# %%
CTCLoss = nn.CTCLoss(blank=0).to(device)

# %%
#train(model, opt, train_loader, scheduler, CTCLoss, device,
#     n_epochs=NUM_EPOCHS, val_dl=val_loader)
# Out:
# 0it [00:00, ?it/s]
# Epoch 0 of 150 LR [0.01]
# 173it [10:03,  3.52s/it]
# torch.Size([2, 180864])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06]])
# 231it [13:26,  3.48s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05]])
# 377it [21:57,  3.47s/it]
# torch.Size([2, 205056])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05]])
# 523it [30:29,  3.47s/it]
# torch.Size([2, 275328])
# tensor([[ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014]])
# 526it [30:41,  3.63s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06]])
# 824it [48:07,  3.49s/it]
# torch.Size([2, 270720])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05]])
# 902it [52:43,  3.91s/it]
# torch.Size([2, 131328])
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005]])
# 1062it [1:02:03,  3.51s/it]
# MEAN EPOCH LOSS IS 3.3313134944596086
# target w l hough in command
# prediction he si i
# target the conservatives soon found themselves leading in the polls
# prediction thi sis  i
# target it is centered on the new haven and its suburbs
# prediction h
# target gairs actions helped to precipitate a double dissolution
# prediction the sisi a
# target he is buried in saint albans cathedral
# prediction h
# target the national debt had skyrocketed
# prediction h
# target royal scottish orchestra
# prediction he i i
# target he attended ohio university
# prediction the sis i
# target the show is also available as a podcast available for purchase
# prediction h
# target she is married
# prediction he e
# target young team of basketball players winning the game
# prediction he i i
# target two children play on the road on a snowy day
# prediction he i i
# target you know st albans sir
# prediction h
# target the photographs show the cup in an uncleaned state
# prediction si i
# target rowses design was in streamline moderne style
# prediction h
# target meanwhile robin is part of a military column in afghanistan
# prediction h
# target something like this
# prediction he i i
# target it is therefore not suitable for vegetarians
# prediction hs
# target he was fired at the end of the season
# prediction hes
# target they settled off the coast in a remote village
# prediction hs
# target the fist bump involves the touching of two closed fists
# prediction h
# target louisville the county seat is to the southwest
# prediction she i
# target further alerts have been issued by news agencies
# prediction she
# target she is a supporter of spanish club real madrid
# prediction he
# target courts have been reluctant to agree to this
# prediction h
# target the fairness of trickledown economics is debatable
# prediction h
# target he also served as chairman of the detroit edison company
# prediction the sis  i
# target the mineral andradite is named after him
# prediction h
# target to fail doing the ordinary is a disaster
# prediction h
# target lincoln alexander above the western end of the main building
# prediction h
# target they are endocentric environments
# prediction he si i
# target how can the data have become corrupted
# prediction o
# target only younger kids camps are held at the site
# prediction i
# target it is also mentioned in the jack kerouac book on the road
# prediction h
# target it may sometimes form stalactites
# prediction the sis i
# target his birthhouse can be visited today
# prediction his
# target she later returned to the show as sister mary joel
# prediction he i i
# target kirk introduced legislation entitled no state bailouts s res
# prediction the cis  i
# target their services retained the name packet
# prediction the sis  i
# target this park also has a outdoor stage for concerts and other events
# prediction h
# target they are both married
# prediction o
# target human beings show empathy most to those in need
# prediction sh
# target the acorn matures at the end of its second season
# prediction h
# target dont argue with me here
# prediction h
# target they relaunched the brand under its own company
# prediction he i i
# target they are often bilateral
# prediction he is a
# target it is the most common variant of the flute
# prediction h
# target can you help me find the author author trailer
# prediction h
# target after this long went on a musical hiatus broken by occasional gigs
# prediction o
# target he was also master of the masonic lodge reform
# prediction the is i a
# target man watching child in hallway
# prediction h
# target students are usually very passionate about their respective halls
# prediction si
# target b s haldane and sewall wright
# prediction he i i
# target he is buried on the indian land not far from daisy
# prediction h
# target the comic was a modest success
# prediction h
# target however the municipal website uses the taipei system
# prediction o
# target the teacher is reading a story to the class
# prediction he
# target read them and wonder
# prediction a
# target doctor thomlinson gave a dwelling house with outbuildings
# prediction h
# target the streets of a chinatown look alike are lit with bright colors
# prediction hs
# target this one likely began as a temple
# prediction hs
# target they had already entered the court
# prediction h
# target what he did was economically justified
# prediction o
# target the province is divided in four cantons
# prediction h
# target the parallel course did not take hold however until the next century
# prediction h
# target he is best known as the drummer of system of a down
# prediction the si  i
# target at my age i need to be playing regularly
# prediction the i a
# target no she had never seen him
# prediction o
# target the name was later shortened to trempealeau
# prediction the is  a
# target we should meet again in about a fortnight
# prediction the si i
# target allen in the firm allen and norris
# prediction o
# target the town common is above sea level
# prediction the sis i
# target a fireman going under the red rope
# prediction he si i
# target morris and ralph vaughan williams
# prediction o
# target she also participated in volleyball
# prediction the si  i
# target he was born in barcelona and died in bastia
# prediction the si i
# target occasionally a bald eagle can be sighted
# prediction she
# target they both have british accents
# prediction h
# target seay also engaged in planting
# prediction see
# target anthony looked at him
# prediction he i i
# target i can send contextual information to it from other apps
# prediction the si  i
# target dino went on to form duva boxing
# prediction he i i
# target these are known as asterisms
# prediction he si i
# target the gel strength is quantified using the bloom test
# prediction h
# target another factor is the cost of land
# prediction i
# target the bulges added to her beam and to her draught
# prediction he
# target if only we are in time he said catching his breath
# prediction the i a
# target its cover was the british passport control office
# prediction h
# target they concluded that the ship was lying in one piece
# prediction h
# target at the same time they are symbols of action and progress
# prediction hs
# target there are anadromous and landlocked forms
# prediction h
# target the little man with a low growl stood still
# prediction h
# target it occurs as wellformed finesized crystals
# prediction the sis i
# target today it is a national historic site
# prediction the sis i
# target i insist upon that
# prediction i
# target without treatment death may occur
# prediction he i i
# target group of males surrounding a female sitting in a chair
# prediction os
# target she was the only daughter to survive
# prediction sh
# target he was captain of the football team
# prediction she
# target strikes are much rarer on humans since they are more aware
# prediction the sis a
# target an old lady consulting a paperback book
# prediction the i i
# target by then half their food had been eaten
# prediction h
# target he held this post for the duration of the war
# prediction he
# target let me breathe
# prediction he i a
# target i said no originally
# prediction the sis i
# target the property is now a quality inn
# prediction he
# target see sea dumping in karantina
# prediction he i i
# target suddenly they could not seem to do anything right
# prediction the i a
# target how does this occur
# prediction h
# target hes so very prompt
# prediction h
# target race dogs run around a curve
# prediction he si i
# target in this verse herod again questions the magi
# prediction the sis i
# target his son christopher o
# prediction sh
# target many young people spent one or more years in such programmes
# prediction h
# target the council normally meets six times each year
# prediction he si  i
# target fightings ceased at nightfall
# prediction i
# target about four miles of this road was built in saugus
# prediction she
# target and at last he yielded and came to her
# prediction he i i
# target the ballena is spanish for whale
# prediction the si i
# target its capital was fuzhou
# prediction the sis i
# target it does not need a recoil pit
# prediction he
# target the play is currently in development
# prediction the si i
# target tomorrow is another day
# prediction h
# target overall the team came fourth in the championship
# prediction he i i
# target he is initially not into the politics of the police department
# prediction he
# target a young baby boy is about to sneeze next to his mother
# prediction h
# target i know glenn wants it to continue
# prediction o
# target another example is north sea cod
# prediction i
# target the region is called kosovo pomoravlje
# prediction the i  a
# target a small sample is taken from the specimen to be investigated
# prediction i
# target goren comes to think of her as his white whale
# prediction o
# target zettel was born in sacramento california
# prediction she
# target the new slogan your life
# prediction h
# target the dolls are then dressed in traditional mayan style
# prediction the i i
# target i was shattered at the news she had passed away
# prediction he i i
# target he supports expanding the current cap on charter schools
# prediction the sis  i
# target the mets previously played at dobynsbennett high school
# prediction thi sis  a
# target in december he undertook a survey of western port
# prediction h
# target it was only that you looked odd
# prediction h
# target it is very similar to cyan
# prediction h
# target he is also an artists representative
# prediction the si  i
# target woods again won the fight by unanimous decision
# prediction a
# target two men were killed and two others wounded
# prediction she
# target the album was a critical and commercial failure
# prediction the i i
# target the unit has fourteen police horses
# prediction h
# target she rejects kevin branding him a phoney
# prediction she
# target never had he been in so strait a predicament
# prediction he
# target it was nominated for a grammy award
# prediction the sis a
# target delhi metro has train stations nearby
# prediction the i a
# target it also might have some challenge involved
# prediction h
# target this is the story of closers in new seoul
# prediction hs
# target traditionally wedding invitations are mailed in double envelopes
# prediction the sis  i
# target how the tradition originally started is unclear
# prediction the sis  i
# target beside the card celias letter was laid
# prediction the si i
# target it is located westnorthwest of williamsport
# prediction the si  i
# target the person is reading a book
# prediction i
# target attorney gerry spence represented the defendants
# prediction h
# target the boats had a complement of fiftythree
# prediction the si  i
# target filiatra has several schools churches and shops
# prediction he
# target you wont tell
# prediction he i a
# target there are no private schools in the town
# prediction h
# target the family lives in the atlanta area
# prediction h
# target submissions are free of charge
# prediction sh
# target he now lives in myrtle beach south carolina
# prediction he
# target the small revolutionary republic had a short life
# prediction hs
# target passenger service was never very profitable
# prediction hs
# target the vessel was stripped of its broadcasting equipment
# prediction hs
# target kabua began his career as a school teacher
# prediction h
# target i blew my whistle
# prediction h
# target i never had any such idea
# prediction h
# target some even consider it beautiful
# prediction o
# target the bible in the beginning
# prediction o
# target the ball games over
# prediction he i i
# target different variations include a scraping sound on the car door
# prediction h
# target hence the settlement of parkgate was born
# prediction h
# torch.Size([2, 198144])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05]])
# target iceman and magma are shown together
# prediction thi sis i
# target the rosebuds for girls and young women
# prediction h
# target the appeal was rejected
# prediction hei
# target prior to world war one truck production began
# prediction he i i
# target preston v mercer in command
# prediction the si i
# target he has worked as a farmer and was a management consultant
# prediction the sis a
# target i didnt cope well that night
# prediction she
# target many mudcats have reached the majors
# prediction he i i
# target the version was more grandiloquent than the geneva bible
# prediction h
# target p a guthrie
# prediction he i i
# target these kinds of widgets are hosted by a widget engine
# prediction h
# 0it [00:00, ?it/s]
# target this completes the proof of the claim
# prediction he i i
# average test loss is 2.79661633496616
# Epoch 1 of 150 LR [0.009990133642141357]
# 352it [20:29,  3.49s/it]
# torch.Size([2, 275328])
# tensor([[ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014]])
# 460it [26:49,  3.50s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05]])
# 462it [26:56,  3.51s/it]
# torch.Size([2, 205056])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05]])
# 516it [30:05,  3.50s/it]
# torch.Size([2, 180864])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06]])
# 573it [33:25,  3.51s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06]])
# 581it [33:53,  3.46s/it]
# torch.Size([2, 131328])
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005]])
# 695it [40:35,  3.50s/it]
# torch.Size([2, 270720])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05]])
# 1062it [1:02:04,  3.51s/it]
# MEAN EPOCH LOSS IS 2.341327511545853
# target bauer was born in graz styria
# prediction aon as sto paas senea
# target in an instant she was free
# prediction ena tan te ta
# target dont you think thats a rather risky course of action
# prediction ation tes o ome as ti col ation
# target a ripping speech he said
# prediction e re ans pa esant
# target ok so i was a little dramatic but you saw what happened
# prediction hetao as ooltion i ae sol acin
# target it is known as the polka palace
# prediction it is knoas to fol of coles
# target the couple live in highgate north london
# prediction the coe ras  in dae o monton
# target the family settled in toronto
# prediction the son e seon te taton
# target thus he employed historical perspectives to serve philology
# prediction tosin pos oo estantos e ser fooai
# target she is after all a former goldwyn girl
# prediction t as a tollas on a bal an ro
# target huave is now considered an isolate
# prediction me is nolciontea in ai
# target in short i had come down on purpose
# prediction theo a conton poues
# target and she bowed under her suffering
# prediction ani  an over soufer
# target his career was controversial both at home and in ireland
# prediction shestani was on toaon bote fomaninaon
# target the castle is built in the renaissance style
# prediction the  alte o as in dete tea ane sta
# target it is owned by townsquare media
# prediction his on bi cosca mai
# target a keepsake was often printed to commemorate the occasion
# prediction the caa was oin proanen te anar atation
# target none were feebleminded
# prediction then a sin in anat
# target but theres no romantic side to heroin  its no good
# prediction e is now o en saelan ie
# torch.Size([2, 198144])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05]])
# target see list of governors of texas
# prediction s aes oen coer rans o paises
# target the rest of the world kept the new zealand title waiata
# prediction theas a mor cactin ean fae laer
# target a happy couple walking down the street and holding hands
# prediction e toa i an ti aia
# target we are the party of the charter
# prediction e a e pin on thi
# target he was buried at putney vale cemetery
# prediction he was bard i omataro sonta
# target a superactinide island is already slotted in
# prediction es som pos af pona on e or ane toenin
# target bullets can be stopped by
# prediction te ani to tlie
# target these staircases go up to a crossover
# prediction thes ais as ol fo cosoer
# target he sometimes carries a large pickax
# prediction heson tan tas a ar tacat
# target one moon of jupiter is named elara
# prediction mon monte oper is nan a lorn
# target a woman who is skiing poses for the camera
# prediction a woin a stein poa fo tin
# target the rest of the underparts are yellowish with dark flank spotting
# prediction his lass to ian e ro y oler on to lai soen
# target it is one of the larger plateau glaciers in norway
# prediction it is on te lorer fa oleaters an nori
# target im going to get you home friend
# prediction in go  tation o
# target two of merrills four children predeceased her
# prediction te wa mras or tolin proesiter
# target the clayton store has a richmond heights zip code
# prediction he caons tol as aertion in i so car ee
# target die verstopfung ist wirklich sehr hartnckig
# prediction she  fas tofos e sa or bentiio
# target he often sings in a madeup language
# prediction he als on ses o  maolinweos
# target he was a boy scout in his youth
# prediction he was avied toton iao
# target modern taxonomists recognise two genera
# prediction mein taciss wie as tantanrar
# target it is notable for its bioluminescent properties
# prediction his is nai of frris a in etien pro sees
# target not right away
# prediction mo ra ra
# target so too with its studies
# prediction soton was a sais
# target his heart grew tender for everybody
# prediction hi so re sion e aerfe
# target say no to war
# prediction s o om ma
# target dunoon may have been important
# prediction temann ma a faan an futen
# target theatre on the other hand is terrifying
# prediction te er olai is ter iin
# target this connection uses three suspension bridges
# prediction thes ontion as as toras o tentin rrers
# target the handgrips are wood
# prediction ein pre an wo
# target likewise the pakistanturkey free trade agreement is due to be signed
# prediction wa was a batanter efresan uran ti ton e sin
# target she also won the most photogenic award
# prediction she als o on e oas toftiin ona
# target im inspector bucket and you can trust me
# prediction aes teboe in centrutiy
# target for all the while they lay safe in this cache
# prediction teo e wan anema on  cat
# target christoph and christian knaut
# prediction teto an petinmot
# target she is after him who offends her
# prediction he is ai an o le ano
# target he also found work on ranches wrangling cattle
# prediction thealion o or onantis maon ca
# target the first two years of studies are preparatory years
# prediction thears tion as steis o poen ta ans
# target this rather can be called an introduction
# prediction his oleartine coor in panrecacin
# target my bad
# prediction a dins
# target papua new guinea is the largest yam market in asia
# prediction a plotin is ioe tan mortianmasin
# target soccer players are meandering over the playing field
# prediction ste aers  a mandeof e canco
# target the area was developed largely for subsistence farming
# prediction theer was enol parian freren sein sfoien
# target he was elected member of parliament from almora
# prediction he as i moer pol e som on maa
# target wrestler jumping in the air
# prediction thes wen tom pin o la
# target hardwicke lived in chichester
# prediction for wi a a tatos tar
# target how does this occur
# prediction aas i ator
# target at that time two survivors of the crash were still alive
# prediction i a u o a as e ca o sto a
# target the building was mostly used for rock concerts
# prediction thee coin was nol siis ermoc cunsiecs
# target the final result will include the result code
# prediction tefi ersol menta ers oultea
# target they also host an annual music festival called lutefest
# prediction he also es tin onsi pesen of coin pas
# target the organisers hope to get sufficient signatures for a debate in parliament
# prediction eeo naer of deucon sanetrors or te ain fone
# target she had studied at newnham college cambridge
# prediction she as end in meon olne panret
# target packages may contain other packages
# prediction ta tis ma tecian of tecites
# target he has sought a new treatment for the disease
# prediction ee s so an maa ta an in
# target whats the timeline for the project
# prediction wes e i  forto catin
# target his recent books have been big sellers
# prediction his meon bo sof in de soes
# target so again we learned a lot
# prediction sia weorn a
# target the video starts with a dark hallway lighting up
# prediction the ta is ter o the tar olwawae
# target the following makes this precise
# prediction the in an mai tresoees
# target this section became the east subdivision
# prediction thes  teion tcan i iste suteion
# target i cant swim
# prediction e fana
# target poisoning can lead to tremors and seizures
# prediction a sin o a tetonas on sasis
# target it was a thing that affected the whole family
# prediction it  was a in ofic tealommin
# target he was a native of dublin georgia
# prediction ie wa na o poe teate
# target the bay is littered with wrecks and has many dive sites
# prediction thepais ei i rres an as banie ses
# target he was also the head coach at olivet college
# prediction he sals o aetut a oee colla
# target apple upgraded the motherboard free of charge
# prediction i on main ton te bo feaoftu
# target he is currently a senior vicepresident of law asia
# prediction he s or atin an astees of roa asan
# target it is locally common
# prediction ie is noi po
# target the ship explodes and kills him
# prediction the sie o ensi
# target you know what i want
# prediction t mo woe wo
# target often deportation is their biggest fear
# prediction a is e foan o teti  tee
# target inside the pericarp of the flower is the hakini shakti
# prediction the sa te tor o  or is aton supt
# target he is also cofounder of the world rolling series
# prediction ie s as actuon ef bol boin saes
# target jupiter has a tropical savanna climate
# prediction thepenteran as to toman tin ras o vennot conete
# target he named the tortoise after his godson
# prediction he mans te colos o  poson
# target the white dog runs across the snow
# prediction the wi ton bon e case st
# target it is southsouthwest of the crater moretus
# prediction thea sa ss asion te traof toraes
# target the song became a modest success as a result
# prediction the so in tecan an moe sota sesoein
# target the facility in sault ste
# prediction hi   an sol scat
# target she tried to participate but nobody listened
# prediction she ane proti eaed of ome lain
# target pelias kills him and takes the fleece
# prediction thewi o an pa to fis
# target they are named interindustrial standards
# prediction the a in t in ar in toscols canders
# target it is limited to twochannel output
# prediction it is onan toe tro canal apa
# target fr diese blutgrtsche mit schraubstollen gab es zurecht die rote karte
# prediction s to tas o tain non seati os caer
# target i didnt have friends
# prediction ta in  caains
# target whitehorse mountain of the north cascades
# prediction me wars on often wo ostas
# target good enough for me
# prediction e na er a
# target it is not a film for most people
# prediction it  is noen ermos tacol
# target yes ada thought she had better go with me
# prediction nes a a toin af  aean
# target will was more polite but equally sceptical
# prediction the was noola te e osct
# target the items are then stored on racks in the cloak room
# prediction the a ins an in ser an ra in theorer
# target it was named for ezra stiles seventh president of yale
# prediction it  was nan of pises tin  feeain otin
# target he lives in greenwich village in new york city
# prediction iens in torane teen ana oe see
# target ordnance in mccarran nevada
# prediction armans in nectain eoa
# target both parties win
# prediction e oi a
# target both his father and mother were cheshire landowners
# prediction es is tol ein oan wer catern anan
# target my friend said i love you
# prediction a fonse aa
# target tonic pupils can occur in neurosyphilis
# prediction aec teos a po  aa sives
# target long live the king
# prediction e on ean e ae
# target did you speak to mr norton
# prediction eis ea to wes tinmormi
# target she was survived by pip
# prediction she was aror otent
# target this behavior seems to be realistic
# prediction this paer sin o en olestic
# target the grimaldis ended up in the guelph towns around nice
# prediction the cemois on to on the tol far an mas
# target eutychius was born at theium in phrygia
# prediction he isis is or e fa in frai
# target the journal is published every thursday
# prediction the torals oo ori ti
# target his younger brother was the linguist elmer bagby atwood
# prediction thes sen ten ear asi an e a aa
# target donohue beat back the challenge
# prediction tea an bea a te ta cionont
# target translators can also be used to provide services to the user
# prediction fenaeas tommainis o to tatie i ese
# target the royal palace is known as istana besar
# prediction thea dones s mola is oe son
# target rainfall occurs mostly during the spring and autumn
# prediction ten al a poars alaean is tain ocom
# target a woman walks holding an umbrella
# prediction thewas an mo o tenonca
# target the acorn matures at the end of its second season
# prediction tea coneturs a ian ee sein ceaion
# target the almohads were thoroughly routed with huge losses
# prediction thean  ton iaeon tii ste coses
# target a rubberized track was added
# prediction a rove te wo stae
# target february the twentysecond i think sir
# prediction te tea e tan setin ain sean
# target this is the role of the demister
# prediction thes as ro wof  imento
# target the shield is supported by two men of different shades of brown
# prediction the ion is pols ote en ete cins af cron
# target a brown dog is fetching something in its mouth on a field
# prediction the pron tis tations on pan ai non orn tae
# target this led to a ladder match at new blood rising
# prediction thes lon o ae monen no lo raion
# target he was born in chambly quebec
# prediction he s o an e ommai ie
# target the level ends when all the enemies are defeated
# prediction his ote on is pine on teaas ef tantao
# target tonya survived the shooting
# prediction te as e an peuntion
# target weather in parc national de nech sar
# prediction mee n or  mauon on den man
# target he later became governor of malta
# prediction hea recin tonaf mote
# target constructions workers work on a railroad
# prediction e teshin neros  one a
# target play some thirties frank wildhorn
# prediction thes o nderi fin aon
# target rescue ships swung into action immediately
# prediction wes i se o i toactin eanaly
# target his brothers name is larry and he lived in staten island
# prediction se oe  ter ais o tos staina
# target the origin of the towns name lies in its geographic location
# prediction he arin tefom i ras in e te ori mocaion
# target the standard botanical author abbreviation pringsh
# prediction theste e ean a oler reraion prancio
# target he first started rapping that year
# prediction he as aion rroin af jar
# target he died in brighton victoria
# prediction he dad in praion ti tori
# target they were among the founders of the republican party in mississippi
# prediction the a anmo e solers afero poe on parn weesi
# target what is to become of us
# prediction es to caas
# target a solar chimney can serve many purposes
# prediction the ol onmanon ser man erses
# target both parents came from fourthgeneration south boston families
# prediction e pa san ro to tinrerion so ason tenmis
# target a man makes bubbles while a nearby child gets excited
# prediction e an ma tofes so a e ba ta i to sa
# target he has wounded men
# prediction he  as ondato dain
# target its simple mechanism was similar to a relay
# prediction thi se nais ion was teaer to oaay
# target sir charles howard
# prediction sr ts
# target shant said the cook
# prediction te so te toupt
# target a woman in a black dress waiting to cross the street
# prediction thelon in o aeion as
# target this has often been an inspiration to me
# prediction thes was ao be an terraion tomma
# target a snowmobile trail runs along dakota heights park avenue
# prediction is non to o traal ron aon e croa rcain
# target he decided to try what fortune had in store for him
# prediction he eid i e tro wa forion oni tolfa
# target the episode was written by series cocreator trey parker
# prediction teea oeton a seis cocae tapate
# target meanwhile faith manages to find peace in her jail cell
# prediction the wa a pa man is eancas of teoo
# target estrela da amadora
# prediction es te a coento
# target the nearby bukit jugra is used for paragliding
# prediction then ananea i tontae es tof faresin
# target its territory is now in eastern croatia
# prediction setai ois non e sin praason
# target those who find beautiful meanings in beautiful things are the cultivated
# prediction telse on gen on aians anano ans a foltonti
# target it is in the central part of the state
# prediction i inan san te foo  state
# target isnt that name a bit authoritarian
# prediction his an dem an veoan taion
# target the melbourne cup was brews last win
# prediction the nolan to i ti a t
# target they adopted a second son robert nearing
# prediction ne a o te sian son lolo ein
# target the canberra college is situated in phillip
# prediction it can ber ran poli sitonn into
# target why i could tell you a story
# prediction wo a e to a t
# target not to have tried is the true failure
# prediction the es a tae o tis i taa
# target they had three children two boys and one daughter
# prediction ten feiolren sovaion  ae
# target when they find them they will be able to return to japan
# prediction tew e an an pea e of tor h tan tein
# target he later killed another sikh
# prediction he  wa tetion to e se
# target he sprang up from his chair
# prediction thes mra a o  cer
# target this was held to be divine retribution
# prediction thes as ons o ba in moin atoneasion
# target it is unclear whether this had any effect on the elections outcome
# prediction it is onfa on te si in nsa tonlatos o ton
# target there is also conversion mode an elimination game type
# prediction he as al so confersionlol e onation inta
# target the sleeve rings encircled the lower cuffs
# prediction thesla pras tan serboe o enecas
# 0it [00:00, ?it/s]
# target it is the third single and final track from the album
# prediction itis atu si an aen sac for aro
# average test loss is 2.062117064700407
# Epoch 2 of 150 LR [0.009960573506572389]
# 5it [00:19,  3.91s/it]
# torch.Size([2, 180864])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -4.0159e-05,
#          -3.1214e-05,  3.6880e-06]])
# 143it [08:19,  3.49s/it]
# torch.Size([2, 275328])
# tensor([[ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0015, -0.0014, -0.0014]])
# 334it [19:29,  3.51s/it]
# torch.Size([2, 270720])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.7933e-06,
#          -1.6287e-05, -5.2683e-05]])
# 532it [31:09,  3.49s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -7.8108e-05,
#          -1.9141e-05, -7.8119e-06]])
# 931it [54:28,  3.50s/it]
# torch.Size([2, 205056])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -2.7344e-06,
#          -7.1339e-06, -7.7367e-05]])
# 995it [58:11,  3.49s/it]
# torch.Size([2, 131328])
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0004, 0.0005, 0.0005]])
# 1003it [58:41,  3.78s/it]
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05]])
# 1062it [1:02:06,  3.51s/it]
# MEAN EPOCH LOSS IS 1.9229573038338268
# target she might be intimate and sad with him
# prediction she ritecin coad safer
# target it has recently undergone a renovation
# prediction i asersonla e din iweranation
# target his position is prop
# prediction his psition mi tro
# target shall we just get a takeaway tonight
# prediction te wegia tapoi andi
# target arthur went outside for some coal
# prediction ater wanolsi fosion chald
# target it is a hardy perennial plant
# prediction the pas p hary proin lpa
# target birsen was born in ankara turkey
# prediction theriston wa bo an cono terf turtie
# target the scheringa museum of realist art is in spanbroek
# prediction the finom musiom ofvrelastar is an spogork
# target his plan became known as the ripley plan
# prediction es tin becam non as te briple ti
# target there s cyclist in street
# prediction thes sitis tan ste
# target the woman is wearing a purple shirt and runs on the beach
# prediction the women is wi of opo thar a ron opi
# target this equity could be used to launch a mobile network
# prediction thes tecin to be ues to lonton kobenaort
# target the nature of the emerald city is changed in the film
# prediction the maturin alsity is ca on thetol
# target he also donated a large amount of items for auction
# prediction he as stoi olaen ai station
# target he was also a pioneer of computer chess
# prediction he was also pinaror copi chas
# target i want to pull his head off
# prediction a wonto pois haes
# target the park center has declined somewhat
# prediction the poarcinter astedcind son
# target each species has a distinct number of rings
# prediction ipaces afs testen te no ris
# target this valley is the source of dudhi river
# prediction thes la is e sos of totut rever
# target think of the luck of it
# prediction tofor te lot afit
# target his wife survived
# prediction she is war siit
# target the latter was a standard history reference for decades
# prediction the la wastan ister reen ordecin
# target i want to become a restaurateur
# prediction o wo o inmerristron urer
# target his greatnephew was george smith patton
# prediction the cralati wais dor et pain
# target krasnodar is the economic center of southern russia
# prediction toston the rs is et o acenter o in muter
# target he was also a member of the british relay team
# prediction he was also n mamber of the proi welatinm
# target these achieved for him a brilliant success
# prediction thes ati pi on teensi
# target services were to wrexham and seacombe
# prediction sidi is w to becton an setar
# target he needed to show legitimate income
# prediction the i tocho legiinat canton
# target kathleen kennedy townsend
# prediction he adlae cir y cho steio
# target the current principal is pauric daly
# prediction he capas pa pori dady
# target for small scene graphs this tends to suffice
# prediction co wol i los tistans to fpie
# target the children know him by no other name
# prediction e sholn kni an bier ofe a
# target everybody tried to forget the scene
# prediction thevi vai citis to eti tii
# target an ambulance is near a pine tree
# prediction a nantur ans i er apite
# target many of the amalfitans in salerno sacked that city and left
# prediction mey of ennoftntin cler o sicte ianlat
# target b cook in command
# prediction he cok in tonad
# target he was one of the great climbers
# prediction he s for cla foirst
# target both are now in the custody of english heritage
# prediction wo an n he custoiven li haice
# target she came to the girls help
# prediction shecanto hecos ho
# target the county line still follows the original riverbed
# prediction the cotrerlisto fos ereno reteda
# target airline workers standing under a plane
# prediction thear lin morcursstin andoclo
# target salad days
# prediction solan das
# target at the time he was not believed
# prediction atei i was e titn
# target these impressive results however may hide a murkier reality
# prediction the is oncresireels i e my hie aterrinca
# target most settled elsewhere in castile
# prediction o sel als sor i cusste
# target canisius mascot is the golden griffin
# prediction teiatis i asco dis tecorde prier
# target destruction of private property will not be tolerated
# prediction the cition al pae poorntedoasi
# target see commercial law
# prediction sa torr lo
# target a little college girl from a school of journalism
# prediction a yii fr is bi oun sco loten aiter
# target the more turbulence the better the degree of dispersion
# prediction the orturins te berit igra tisprtion
# target wilson as the first mayor
# prediction wolson as te fors tmaer
# target bono is a leading advocate for drug abuse prevention and treatment
# prediction oes oldelot cet topis ventoantate
# target she was born in sainteustache quebec
# prediction she is bin an sa i sa cback
# target it was tampa bays first stanley cup in franchise history
# prediction it was taobas fost stanycop in franthascister
# target it is near the villages of brackenfield ashover and clay cross
# prediction it is nateelgo ar paantiol oselvo ca cas
# target the dolly copp campground is located here
# prediction the dol co angrn fo fai yer
# target so i called them up and asked them
# prediction sico d mt in laston
# target length in kilometers is in parentheses
# prediction then tinconerers tisonn fo tceae
# target it peaked at number nineteen in new zealand
# prediction the catet noer li ta and iilind
# target brown tendered his resignation eight days later
# prediction tontome is was aition a tisdeta
# target he travelled through france to rome in italy
# prediction he toe cn fies to lolin id
# target just the room
# prediction sos folon
# target his main residence is in bel air los angeles
# prediction is na waentofm ller oapa
# target it must not be lost
# prediction it bas not te lat
# target congressman and governor john page
# prediction o wesmenin goena jo ps
# target he was best known as the why not
# prediction he was be non as bolir no
# target he has none and no anger
# prediction the has no anowinger
# target he swelled attendance at wranglers home games
# prediction hes wa cantins sa riter holtas
# target if he were to die you would be the master
# prediction teh was it e wis pat loto
# target three young guys working in a dark room
# prediction sdan gis wi in o aur
# target stype stars with masers are uncommon
# prediction e to stos wor te laos iai cone
# target he cited a desire to spend more time with his family
# prediction hes tid it thesir is pen or ciof isteny
# torch.Size([2, 198144])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05]])
# target ahmed he also wrote songs for shalimar pictures
# prediction orec il sore sons for shaan mo fiche
# target doctor doreen o ryan is currently principal
# prediction to ciderain l riin is cor ly cricia
# target treatment is guided by extent of disease
# prediction toipin is cii bi stno dsis
# target two complete onehour shows
# prediction the conki won o shits
# target the size of nanocrystals distinguishes them from larger crystals
# prediction the siies a nacristlels i tenicis e  form largr crustels
# target he was made a pastor in alassio
# prediction hewas paed of pastrn aastir
# target the same sentence was confirmed by the appeals chamber
# prediction the saimtins was en forned byi cis champer
# target in ireland it has a much more localised distribution
# prediction the irei was luano cos e pition
# target weather in parc national de nech sar
# prediction mader and par natinol de nat so
# target start off with the glimmering landscape
# prediction sotas wit e tbarin rasta
# target his form for north queenslands first season was mixed
# prediction his foon folof cas on forcason was mad
# target the couple did not have any children
# prediction tpe i elto pa ae teer
# target the house was assessed to be worth ninety thousand pounds prior to the flood
# prediction the has s osese wo e any talsin co piro pla
# target nine are preserved
# prediction no a tosid
# target you cannot be shown
# prediction he canot pe shiol
# target he is married and has two children
# prediction heis nar an has twonchilten
# target get me the man
# prediction to ma bei
# target in the past the german name was domschale
# prediction an pas the gomin nan was dotr
# target i stood looking at him in silence
# prediction a slr inatin ind side
# target it was now eleven oclock
# prediction it was aot ilean apok
# target snow was observed to fall from cirrus clouds
# prediction to was olte te fiton sai stoe
# target it is the county seat of stephens county
# prediction it is a couyseto  st fo cody
# target the series was then discontinued
# prediction the ciis was tan dis ontene
# target four individuals walk down a street with two holding hands and one holding a guitar
# prediction trr aas mn orstrin o to oin ons an wonorin toto
# target after their exchange the two departed coolly
# prediction atoraer a tins sme tror air et tudin
# target made his own lake
# prediction the is ol li
# target the school has been involved in two controversial incidents to date
# prediction the sco as anfol an turcutorrershialins iits toda
# target it is insectivorous and nocturnal
# prediction it is an setibors a no to
# target it is currently open as a museum
# prediction it is curntly i anas n uan
# target the music in the album was all composed and arranged by kikuta
# prediction the musen nape was al a posin raed by ticoter
# target it is the only law school in the state of new hampshire
# prediction hi is nowte was sco  tar in ater
# target housing is of goodquality in general
# prediction owsinn is oni col tein elo
# target the crashed meteor left a gigantic crater on the ground
# prediction the cuse orof to tetet i cratorin gro
# target shew helped in organizing her funeral even purchasing the coffin
# prediction she aotin o reisaeiro is opas ton thecon
# target in the short term the reforms stabilised the economy
# prediction en e solton drfol i stals econi
# target the line is not electrified and all trains are dieselpowered
# prediction the li is morpeaefi an olta siy apali
# target it stars bob monkhouse
# prediction its ta fot lon co
# target she dies the house survives
# prediction she dis te hl sbit
# target english is also spoken as a second language by many
# prediction agi is alsospocon as a sectlawit irey
# target i shook my head wondering even what it was
# prediction i si miared wondorn eid woti was
# target this did not apply to bonus jackpots
# prediction thestian a ied gon stacco
# target no specific categories were chosen
# prediction thes piti fetitois pa toser
# target middleton served in a variety of public offices in south carolina
# prediction teaconser in teridi ofe foces in sufterline
# target the melbourne cup was brews last win
# prediction the lolen toy stas wacor
# target a small dog walks with men in the city
# prediction o wo or aas w a in the sin
# target several scenes from the book take place in his apartment
# prediction ssins son tebo tapa ins apoldr
# target auf das was jetzt kommt habe ich nmlich absolut keinen bock
# prediction the fespufsits co iis asti cando
# target the flowers are windpollinated catkins
# prediction e foba olti pi lecer a
# target while heated over a fire all ingredients blend together well
# prediction wo e tore fiar olin reiins plito git te wo
# target modern herbalists also use it to treat catarrh and kidney stones
# prediction aan halis al sus t totra coa anckin e sta
# target fortunately no lives were lost in the incident
# prediction tin ain ories we ofst natent
# target we only sell organic food
# prediction woone solor danafo
# target he formed a new government later that day
# prediction he fa an o goet wy terat da
# target since father died sir ive gone out to work
# prediction he foe di se  ten ao
# target take it away my dear
# prediction he i la igeer
# target a group of asian young adults are gathered in a classroom setting
# prediction the o atin no ai tfart iancotin
# target harris was his wifes maiden name
# prediction ares w hisis wa tewa
# target keep your temper my good fellow keep your temper
# prediction he icun o mie fe kecioumpe
# target nogger black has a logotype that looks like graffiti
# prediction wowerlu hasalobeba te  sicdoity
# target a young girl enjoys a frozen treat by the pool
# prediction the angero aas frosintra i co
# target but then belboz suddenly disappears
# prediction me o dan ollo seli i a pars
# target the band also featured al scott on bass at some gigs
# prediction the dadalsorfiton als sco on bion somgas
# target this added greatly to rural poverty
# prediction thes said briitor ro opety
# target oil and ranching remain important to denver city
# prediction a orlinrantin erninpurnto im pisi
# target also the county is home to several attractions
# prediction ose the contys hol te sevvl of tactions
# target three israeli soldiers were killed in the operation
# prediction t is er o solis worcilin aersion
# target he had not finished his job
# prediction he ha no tiniti stol
# target he was not appointed and instead tim nielsen took over
# prediction he was ta opited in ha stetan oalsontebalver
# target for example seated presses may be done while standing
# prediction tordinpll seen pe mateden no standin
# target two outer wing tanks each contained of fuel
# prediction toe wltobin tens i coa o tobo
# target you know me and i know you
# prediction healy aoer
# target she also participated in volleyball
# prediction she as to potis pua todoio
# target what are the interdependencies of the application
# prediction wo oty an to the ponn saes of tetocation
# target stolz is signed to ford models
# prediction as is fied to forodes
# target it is a bird of woodland often near water
# prediction its purd of wodent ftin a water
# target it is always written in the third person
# prediction heer wis oonn a tafutiter
# target she never officially announced her retirement
# prediction she ever of fitioll ian ows tor wet tirt
# target hebi has several coal mines
# prediction ay ha sel co lis
# target so did the others
# ...
# prediction the heoprenmetion totor ot
# target in the company he also appears as a fan favorite
# prediction in the compay he also apears was a fan fibreel
# target he has two daughters from his first marriage
# prediction he is tododi fror is fors marage
# target abati was a satirical poet who wrote in the baroque style
# prediction oberty was e seterito po fuded in the boto stase
# target king stakes himself instead
# prediction kang staks im sel in stad
# target the council normally meets six times each year
# prediction he caunso nobely met suxrons tec ear
# target doesnt even come close
# prediction us ni comclofs
# target to prevent the train rolling back the brakes were applied
# prediction topreben the fran royvas the brat for fod
# target can you search the picture titled the accounting
# prediction pe surts tepitul titleld te conting
# target thats how he spotted me
# prediction thet ois spadedy
# target these ideas are universally accepted
# prediction he saes a inecitisete
# target it is currently a part of the tacoma public school district
# prediction it is cerely aportof ticobe obe scuo distrend
# target his form for north queenslands first season was mixed
# prediction his forl for tor crensons for season was liedsl
# target the story also features the beatles in a film clip
# prediction the story also feature s the betles in a filqert
# target he remained very popular until old age
# prediction he reain very poculerintoaelageese
# target in each chart the plaques are dimensional submanifolds
# prediction he e curtd the pixs ar themintiu sut miifors
# target three men dressed in white playing kettle drums outdoors
# prediction thre men grestin wit plang catledrems ar to
# target and even so  what right have you to pull them she asked
# prediction tink iel so wat rater ou tepover shes
# target each mast carried three sails
# prediction therest caid tro sas
# target this prompted her move to a house near reading
# prediction this pontec renliter hos e redis
# target reflecting pools and fountains spread throughout the compound
# prediction relickan pols ind fountin sprea treou the conprond
# target a lot of people walking around outside of a building
# prediction elit o peple woding aro tun sie of ar building
# target borden was however elected again for halifax
# prediction or as porbenlito the gin for holifes
# target its capital is kaya
# prediction this cotee is cieslt
# target a man in a green shirt leaning on a pole
# prediction a mon in a gre sho laing on the for
# target he is known for his signature calls of goodbye
# prediction he is kno for is sinitipos of pebo
# target the relation between such propositions
# prediction terrilation eten suchpropositionsseselob
# target i wonder if it feels lonely
# prediction themonneis a isiololyaiae
# target the western border of the suburb is marked by the gateway motorway
# prediction the we en bode soer is mortd by a kewa mode
# target this was certainly familiar before hilbert
# prediction this was sertly fennilyor be four hilberd
# target this was used among others by julian tuwim
# prediction this was sus on uniles byeian toi
# target the bridge was built by the oxford mason john townesend
# prediction the broge was boed byhe otro mason jonton end
# target they are such pros
# prediction y ars switcros
# target it is a multipurpose stadium
# prediction it is a mosite of tistadiooe
# target a public announcement followed the ceremony
# prediction the puble inasbenforlyd de serman
# target voluntary enclosure was frequent at that time
# prediction rontran closers was rrecei e tisee
# target shall we go up in the lift or shall we take the escalator
# prediction owegop in the wist or shorweta theiscatrer
# target in essence he was the life of the party
# prediction hen esince he was alatof o the paryll
# target i stood awhile in thought
# prediction pi stode wiin bod
# target however this was soon to change
# prediction however thes wat son the ja
# target fort ridgely state park is nearby
# prediction fordrily i ta o tiseba
# target two dogs playing in a field
# prediction two gogs playing in a feod
# target the borough borders franklin township and cumberland county
# prediction the boabo dis frenten tounsip af coin contry
# target this compound is then secreted by the patients body
# prediction thes commpowd is then ucreted by the pations bory
# target our state does not have a climate for job creation
# prediction ar stat is non o ecloif forjocreationaie
# target a white dog is standing on a grassy hillside
# prediction a wi do i staing on a gracivelsi
# target the project initially drew some criticism
# prediction the projectonnutially dres im creiceson
# target thats brilliant i think
# prediction abriian i tenk
# target the family attempts to get a prize at the carnival
# prediction the fally attenes tegea prie at te cornivle
# target the production later transferred to the west end
# prediction the protociollity i frosfer to te es in
# target its just the thing
# prediction its justd te ti
# target students attend meadowbrook high school
# prediction stedens atan mel rerpiscoololtetet e
# target perhaps it is paid already
# prediction reas i is pado redy
# target the reasons for the withdrawal are unclear
# prediction the resein es fotewifto foronty
# target the data are protected for confidentiality
# prediction the ate erpotected for conpredinsariy
# target its county seat is amarillo
# prediction its county seat is ummerenehlete
# target today chief occupations are fishing and tourism
# prediction today je otupations ervisiong anturson
# target i must master that
# prediction i es mesteders
# target the zoo is the largest zoo in ecuador
# prediction thise is the larces su in accudo
# target two girls riding on swings
# prediction fe togirs ridi on sins
# target a skateboarder slides down a metal railing
# prediction the ska bordersli down o mete ron
# target the ambulance is on its way
# prediction the aelans tis on ly swa
# target the link for windows drivers has been removed
# prediction the wink frorwindes drivers has beenemued
# target oconnor charity fund
# prediction the corer hurdy fomehlt
# target the following years were not nearly as successful
# prediction thefo ears were not narly as sucessful
# target the schools mascot is the rising sun
# prediction the scoos masicot is the rising so
# target he was replaced by new lead curtis young
# prediction he was supplaed by nuele crutes guns
# target collins and major chuck yeager
# prediction cos an majer trip eater
# target he then went on to direct minor films
# prediction he te worin to tarit monfils
# target grusin is married to nan newton
# prediction rruson is married to nan muvise
# target text programs are easier to write smaller and run faster
# prediction theprorensar isi to rraloter abepesiten
# target a woman in a white shirt playing volleyball
# prediction e bomen in e wa shirt paying voyble
# target he was left in his cage
# prediction he was te lefst inus cae
# target these are available in both print and electronically
# prediction the arrawasbu trit armetor
# target he received his information from court records
# prediction there seived dis enpomation fom cortrecordsaie
# target a stickle is a hill with a prominent rocky top
# prediction e sticce is a ill with the promie ropetof
# target a couple enjoying the night lights together
# prediction  in eion oplntouna lace
# target they proved to be exceedingly popular
# prediction the proved to b ecetingly potor
# target during workups she lost two aircraft
# prediction theri wor bots she was to aircrot
# target you must find a can of worms to get this power up
# prediction hemas for a lycana woren siat thisporsitse
# target shriekback are still actively producing music
# prediction she refet for sto ectef teproduci usi
# target three sisters in matching pink dresses standing on the beach
# prediction thereiss temethi pentresss  stay onta
# target it is owned by power corporation of canada
# prediction it is aned by coo coperation wof cauter
# target a majority was required for election
# prediction the mojari els required for lation
# target both albums were released by caroline records
# prediction thes altums weleed the colyreces
# target however the higher frequency often brings advantages
# prediction howewer the iaf rrepinsy ofen bris aden dages
# target joscelin was rewarded with the county of edessa
# prediction te len was revorded with the comteovadise
# target he lived at the ropewalk nottingham
# prediction ei atrubot notinden
# target a woman wearing a black jacket is walking on a sidewalk
# prediction foove weri lex jecxes is foting on the site
# target he signed his art as c krieghoff
# prediction he sie i ar is se freko
# target she identifies as bisexual
# prediction she ten tofies atis by situ
# target dismiss her patronage from consideration
# prediction this misst er patrea fren consideration
# target he was killed in battle
# prediction he was kiled in mow
# target aristocrats shunned it as a peasant drink
# prediction oris te crap shiondi as a pisen dretoltl
# target that same year the medical schools new clinical departments were opened
# prediction the so u the meipo scoos eciiccal the prormits were open
# target oh what is the matter
# prediction o wat is the metrer
# target tala is the mistress of her own part of hell
# prediction oer is the mistrers ofronorhi
# torch.Size([2, 198144])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05]])
# target banner hill is a suburb of erwin
# prediction temeti is a suberbaf arry
# target his short story the flood has been translated into english
# prediction thes srostory the flo as bentranenclated in dalishagsgsl
# target it was repeated on just two occasions
# prediction it was a repeted undusto asions
# target it is an allboys school
# prediction it is an al bus school
# target a person is riding in a boat on a lake
# prediction a pursion is rady in a bo on the lae
# target admit that you have been unable to do so for the past yearandahalf
# prediction it i the u tealible to do sof or the paster an er
# target it consists of two platforms
# prediction it consis of to performs
# target he was remarkable for his humility and piety
# prediction he was reorcoble for tis umulityan piitye
# target many were unsafe and costly to maintain
# prediction the u wori sesins of secmenteestese
# target a dog leaps over a wooden fence as another is about to
# prediction the dogy covera woin fen is mother res aboptu
# target it has the largest area of unfenced common land in england
# prediction it has the nogestene of ben finc collolanled ingund
# target i was fined for returning the library book late
# prediction i res fiin te reteringded wivery ofly
# target for example seated presses may be done while standing
# prediction fer dexemple sete presimabedan mol standi
# target fox an assistant surgeon on the expedition
# prediction far an a sisted sidin on te expiditionaseoterte
# target the behaviour is rough and the fish often jump out of the water
# prediction the beever is ro in the fese ofpenjubon of the warder
# target lipscomb does not have fraternities and sororities
# prediction thitsgon dis knot ha forturtys oersorrooties
# target legend says also they had in total ten sons
# prediction legon sas also verein toin tinsons
# target a girl in a green bathing suit leaping into a lake
# prediction a girl in a gren bading su pyping inoellak
# target i can hear wilko in lots of places
# prediction i can ewil coy lofs of plaes
# target a hospital in the city was established in her memory
# prediction theete te ce was i soblition amonlo
# target he remained somewhat rueful though no longer bitter about it
# prediction he emainn somon worl for to no longger biderbai
# target highpressure lamps produce very bright bluish white light
# prediction iperiallens produ very brit buish woartlif
# target at high tide access is a difficult climb down the cliff
# prediction a rita dasiesis te diffice cri down tot cuf
# target he is usually depicted with a bag full of valuable objects
# prediction he isusual depicted with the baed for  vaive ofjuts
# target keenanbolger starred as mary flynn in the encores
# prediction kilen bolger sto is marryfle of te uncles
# target the quorum for privy council meetings is four
# prediction the corin ser prote counso redings is for
# target this set in motion a new leadership crisis which lasted almost six months
# prediction the sarmlo so in nylidisoprae swir lesed on te sulots
# target the system was never supposed to be a huge seller for atari
# prediction thi sister was no as posedto ve ay seior firs
# target alwal was a prime area under the british cantonment
# prediction ao was fron ara on the te griscran onbens
# target he moved to england
# prediction helo ticti ris
# target from bristol
# prediction from briste
# target the northern boundary is the railway line
# prediction e oder bantreised to rewalos
# target later that year ray became a christian convert
# prediction later ther year ra beca a criestu cober
# target american eagle continued the route after the merger
# prediction lotlo contonu terly anpimeite
# target that was a very interesting lesson she said
# prediction do the berry intrisilesson kesod
# target we die under your stone ceilings
# prediction le doy anlayors to seles
# target newscasts are simulcasted to both stations
# prediction heis cused ar so upested deblu stasionso
# target he is a director of dubai bank
# prediction ie is ate recter of te bi bond
# target fourteen cars participated in race
# prediction fortein corss prejusipated in os
# target a civil funeral took place at lenkom theater
# prediction the cirel vadel toplased laco saser
# target mccarron manages to deliver the infant alive and well
# prediction recaro meius to te lofvirthe infentowi e werl
# target i clung desperately to the words of peter
# prediction ilor disperilyed to the bos of peter
# target he has played twelve caps for his country
# prediction he is plete cot for is contry
# target she continued her remarks
# prediction she contiu er remarks
# target he was the son of a lutheran minister
# prediction he is the soliteliin lilisters
# target he was created by simon spurrier and artist carl critchlow
# prediction he was coreated by somin sviia ad otis col critul
# target the following day he was claimed by the washington capitals
# prediction the followingda he was cland by the wosionton capitels
# target it tastes strongly of iodine
# prediction it a stoly ofaedise
# target dibens lives and trains in boulder colorado
# prediction dibins livves an traineds in bulder colleroa
# target the contact was limited but it was at full speed
# prediction the pontic was ebecatebeytaser fu spedy
# target three people giving a presentation before a crowd
# prediction fre pepeliing of pisicatiton e for
# target they toured around europe and north america mostly as support
# prediction the tordaroour of ben northe merita mos le i suppor
# target a celebration in king arthurs court follows
# prediction a sobasion into otis co follos
# target the group subsequently disbanded
# prediction thet te coks ubchipentexunded
# target it is eaten with bread
# prediction it is acin ri brat
# target the underfur is paler in color
# prediction the counderfer is paler in coler
# target the modern term for this meaning is ultrasonic
# prediction the moden tem for the se is orte soni
# target the toes contain lamellae
# prediction he tos conan themellot
# target peleaga is located in the park
# prediction poliorder is wocated in the bork
# target there are a few exceptions known
# prediction thee ar fe oxsuptuos knownl
# target he also centralized control over supply
# prediction he also fenturullis contro over soppli
# target im a comedian doing radio
# prediction an te commution do radio
# target a man dressed in full santa attire with beard and glasses
# prediction the main destinful santer tir wih beed in lanses
# target john dowland visited him in italy as well
# prediction jon dowlan visideddeam anmevely is well
# target kids chasing a soccer ball
# prediction ias tusin te soffivlel
# 0it [00:00, ?it/s]
# target timothy played herriot in the television series
# prediction twoesepla erriat in tytobision seris
# average test loss is 1.3849328603336517
# Epoch 8 of 150 LR [0.009381533400219317]
# 50it [02:53,  3.44s/it]

# %%
def beam_search_decoding(output, answ, answ_lens, blank_label=0, width=8):
    decoded_preds, decoded_targs  = [], []
    
    text_transform = TextTransform()    
    
    for i, mat in enumerate(output.transpose(0, 1)):
        last = {}        
        P_b, P_t = 1, 1
        P_nb = 0
        # dict       [0:prob_blank, 1:prob_not_blank, 2:prob_total, 3:list of ]
        last[''] = [P_b, P_nb, P_t]
                        
        for t in range(mat.shape[0]):
            curr = {}
            
            # sorting
            cand = [(key, el) for (key, el) in last.items()] # листы pb pnb pt beam
            sorted_cand = sorted(cand, reverse=True, key=lambda x: x[1][2]) # P_Total
            best_beams = [key for (key, el) in sorted_cand][0:width] # лучших w штук bшк
           
            for beam in best_beams:
                P_nb = 0
                if t == 0:
                    beam = ''
                else:
                    if len(beam) > 0:
                        last_num = text_transform.text_to_int(beam[-1])
                        P_nb = last[beam][1] * mat[t, last_num]

                    P_b = last[beam][2] * mat[t, blank_label]

                    if beam not in curr:
                        curr[beam] = [P_b, P_nb, P_b+P_nb]
                    else:
                        curr[beam][0] += P_b
                        curr[beam][1] += P_nb
                        curr[beam][2] += P_b + P_nb                
                
                # 0 is blank
                for c in range(1, mat.shape[1]): 
                    new_beam = beam + ''.join(text_transform.int_to_text([c]))                    
                    
                    if len(beam) > 0 and last_num == c:
                        P_nb = mat[t, c] * last[beam][0]
                    else:
                        P_nb = mat[t, c] * last[beam][2]
                    
                    if new_beam not in curr:
                        curr[new_beam] = [0, P_nb, P_nb]
                    else:
                        curr[new_beam][1] += P_nb 
                        curr[new_beam][2] += P_nb                
            last = curr
        
        cand = [(key, el) for (key, el) in last.items()]
        sorted_cand = sorted(cand, reverse=True, key=lambda x: x[1][2])
        best_beam = [x[0] for x in sorted_cand][0]
        
        decoded_preds.append(best_beam)
        
        # i - номер бача
        decoded_targs.append(
                text_transform.int_to_text(answ[i][:answ_lens[i]].tolist())
        )
        
    return decoded_preds, decoded_targs

# %%
test(model, opt, val_loader, CTCLoss, device, bs_width=8)
# Out:
# target:  he started violently
# prediction:  hs ter fi
# beam_search_preds:  this ter fise
# target:  i think it is
# prediction:  i then etis
# beam_search_preds:  bi  theng etes
# torch.Size([2, 198144])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.8324e-05, 7.6901e-05,
#          3.2309e-05]])
# target:  a boy is sleeping in his dinner bowl
# prediction:  abi seping in as tat
# beam_search_preds:  ta bi seping in as ta nrllltttt
# target:  a woman in gray cuts cake
# prediction:  a won in gray cat
# beam_search_preds:  ta  won in gray cats
# target:  is she as good as you say
# prediction:  the se as boreses
# beam_search_preds:  the se  as boreses
# target:  flaming youth
# prediction:  flaiin ou
# beam_search_preds:  ffllain ou
# target:  list of mirmo
# prediction:  he list bof e ammo
# beam_search_preds:  the list  of e ammol
# target:  you have a couch
# prediction:  he ha a cand
# beam_search_preds:  the  hav a cand
# target:  no but suppose she was
# prediction:  tbaswas sho
# beam_search_preds:  t aswas sho
# target:  a group of hikers hike
# prediction:  the gro of hatis ha
# beam_search_preds:  the gro of hatis hag
# target:  he lost his first match
# prediction:  he  lase fet mech
# beam_search_preds:  yhe  lasse  fert metch
# target:  it was fun
# prediction:  i was fon
# beam_search_preds:  tit  was  fon
# target:  warren and son
# prediction:  warin anson
# beam_search_preds:  warrin  anson
# target:  whats up
# prediction:  watter
# beam_search_preds:  wat er
# target:  live and let live
# prediction:  tev fon tedes
# beam_search_preds:  tev fon tedess
# target:  afraid it might rain
# prediction:  ope if mi flen
# beam_search_preds:  t o pe if  mi flen
# target:  will it snow in granbury
# prediction:  lit kno in gron
# beam_search_preds:  w lit  knot in grongrr
# target:  maybe it will
# prediction:  wle i wo
# beam_search_preds:  wme i wo
# target:  tony lilly in command
# prediction:  nny leilly in cna
# beam_search_preds:  wnny leilly  in cmand
# target:  allerdings
# prediction:  ilomins
# beam_search_preds:  wilomins
# target:  he was not alone
# prediction:  he was notta lon
# beam_search_preds:  she was notta lon
# target:  the schools athletic teams are known as the red raiders
# prediction:  e atante
# beam_search_preds:  te at ante
# target:  and they passed on
# prediction:  i the pas on
# beam_search_preds:  bin the past on
# target:  you dont say so
# prediction:  do sasel
# beam_search_preds:  tdo sasel
# torch.Size([2, 200448])
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -8.9087e-05,
#          -5.9199e-05, -5.9370e-05]])
# target:  as you wish
# prediction:  i ye ise
# beam_search_preds:  ti ye isseeeeee
# target:  whom are you calling now
# prediction:  n i coing a
# beam_search_preds:  wn i corling na
# target:  theres the rub
# prediction:  theres ther rob
# beam_search_preds:  thereis ther roub
# target:  care for the sick
# prediction:  kar forte se
# beam_search_preds:  skar forte se
# target:  we can both hear
# prediction:   wten o
# beam_search_preds:  t wt en o
# target:  id like to think
# prediction:  i li for fin
# beam_search_preds:  bi li for fin
# target:  what is it now
# prediction:  what is it now
# beam_search_preds:  what is it now
# target:  that was my first thought
# prediction:  the is na forst tark
# beam_search_preds:  the is nav forsst ark
# target:  wie kann man sich schtzen
# prediction:  te cone shise
# beam_search_preds:  te con e shilse
# CER 48.82082145759296
# CER BS 50.6209678653425
# WER 84.74335709184193
# WER BS 88.5725581937703
# average test loss is 1.604088331713821

# %% [markdown]
# target:  they are also used for local level polling
#
# prediction:  they are also used for loka level polling
